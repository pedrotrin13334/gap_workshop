# %% [markdown]
# # <center> GAP WORKSHOP - DIA 1 </center>
# ## <span style="color:blue"> <center> Universidade de Brasília - UnB </center> </span>
# ###  <center> Autor: Pedro Henrique Andrade Trindade </center>

# %% [markdown]
# ## Primeiramente, onde estou?  👀 🤨
#
# Bem vindo ao Jupyter notebook! Aqui podemos escrever nossos códigos de maneira bastante didática e sequencial, enquanto o computador faz todo o trabalho por trás :)
#
# - **Vamos começar pelo começo**: Neste notebook temos basicamente dois tipos de células, uma para texto e outra para códigos (que no caso utilizaremos a linguagem GAP).
#
# O texto aqui é escrito com a linguagem Markdown (podemos utilizar HTML também, para algumas estilizações).
#
# Markdown é uma linguagem de Markup, o que significa que basicamente ela diz como o texto tem que ser e aonde tem que ficar.
#
# - Por exemplo, podemos escrever *headings* de diferentes tamanhos:
#
# > # Heading 1
# > ## Heading 2
# > ### Heading 3
#
# - Podemos escrever em **Negrito** ou em *Itálico*.
#
# - É possível representar texto em latex: $\sum\limits_{i=0}^{\infty} \phi^2(i) + \prod \frac{x+y}{x^2}$.
#
# - Podemos desenhar tabelas:
#
# | Nome1    | Nome2 |
# | ----------- | ----------- |
# | Dado1      | Dado3       |
# | Dado2   | Dado4        |
#
# - Também conseguimos fazer listas:
#     1. Isso é um elemento.
#     2. Isso é outro Elemento.
#     3. Mas um outro.
#
# **Agora** que sabemos o básico de Markdown, podemos começar a colocar a mão na massa!

# %% [markdown]
# ## Mas o que é GAP?

# %%
Display("Oi eu sou o GAP :)");
# Out:
# Oi eu sou o GAP :)

# %% [markdown]
# **GAP** é um sistema para algebra computacional discreta, com uma ênfase em particular em teoria dos grupos computacional. O GAP proporciona um linguagem de programação com uma biblioteca com milhares de funções implementando algoritmos algébricos escritos, assim como uma grande biblioteca de dados e objetos algébricos.

# %% [markdown]
# ## Mas por que GAP?

# %% [markdown]
# Com o auxílio do GAP é possível testar numericamente e propor conjecturas baseadas nestes testes (nem mesmo o Euler conseguia calcular o que hoje conseguimos em apenas um clique!).
#
# Intuição é essencial para trilhar o caminho de algumas provas, que de outra forma poderiam ficar obscuras pela complexidade numérica.

# %% [markdown]
# ![grothendieck](https://upload.wikimedia.org/wikipedia/commons/e/ef/Alexander_Grothendieck.jpg)
# #### <center>"Uma pessoa não deveria tentar provar nada que não seja quase que óbvio" - Grothendieck, Alexander.</center>

# %%
LoadPackage( "jupyterviz" );
# Out:
# true

# %%
max_number := 1000;;
primes_counted := 0;;
acc_primes_list := [];;
for number in [1..max_number] do
    if IsPrime(number) then
        primes_counted := primes_counted +1;;
    fi;
    Add(acc_primes_list, primes_counted);;
od;

title1 := Concatenation("Quantidade de números primos até ordem ", String(max_number));
Plot([1..max_number], acc_primes_list, rec(title := title1));

x_log_list := List([1..max_number], x->Float(x)/Log(Float(x)));;

division_list := List([1..max_number], x-> Float(acc_primes_list[x]/x_log_list[x]));;

Plot([1..max_number], division_list, rec(title:= "Relação assintótica entre x/log(x) e a quantidade de números primos"));
# Out:
# "Quantidade de números primos até ordem 1000"

# %%
max_order := 200;;
groups_tested := 0;;
abelian_counted := 0;;
percent_list := [];;
for order in [1..max_order] do
    group_list := AllSmallGroups(order);;
    groups_tested := groups_tested + Length(group_list);;
    abelian_groups := AllSmallGroups(order, x->IsAbelian(x));;
    abelian_counted := abelian_counted + Length(abelian_groups);;
    Add(percent_list, Float(abelian_counted/groups_tested));;
od;

title1:= Concatenation("Razão de números abelianos até ordem ", String(max_order));;
Plot([1..max_order], percent_list, rec(title:= title1));

# %%
x := [1..10];;
func := x -> x^2;; 
y := List(x, func);;
Plot(x, y);

# %%
s4 := SymmetricGroup(4);;
c5 := CyclicGroup(5);;
g := AutomorphismGroup(s4);;
StructureDescription(g);
# Out:
# "S4"

# %%
Elements(s4);
# Out:
# [ (), (3,4), (2,3), (2,3,4), (2,4,3), (2,4), (1,2), (1,2)(3,4), (1,2,3),   (1,2,3,4), (1,2,4,3), (1,2,4), (1,3,2), (1,3,4,2), (1,3), (1,3,4),   (1,3)(2,4), (1,3,2,4), (1,4,3,2), (1,4,2), (1,4,3), (1,4), (1,4,2,3),   (1,4)(2,3) ]

# %%
lista := [];;
for e in Elements(s4) do
    if Order(e) = 3 then
        Add(lista, e);;
    fi;
od;
        
Display(lista);
# Out:
# [ (2,3,4), (2,4,3), (1,2,3), (1,2,4), (1,3,2), (1,3,4), (1,4,2), (1,4,3) ]

# %%
g := Group((1,2,3));
# Out:
# Group([ (1,2,3) ])

# %%
Elements(g);
# Out:
# [ (), (1,2,3), (1,3,2) ]

# %%
StructureDescription(g);
# Out:
# "C3"
